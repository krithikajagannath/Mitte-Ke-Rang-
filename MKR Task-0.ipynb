# %% [markdown]
# # Mitti Ke Rang- Round 2 Task

# %% [markdown]
# ## Name: Krithika Jagannath

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d = pd.read_csv(r"C:\Users\krithika jagannath\Downloads\MENTAL HEALTH DATASET.csv")
d.head(n=10)
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
# 5  2014-08-27 11:31:22   33    Male   United States    TN           NaN
# 6  2014-08-27 11:31:50   35  Female   United States    MI           NaN
# 7  2014-08-27 11:32:05   39       M          Canada   NaN           NaN
# 8  2014-08-27 11:32:39   42  Female   United States    IL           NaN
# 9  2014-08-27 11:32:43   23    Male          Canada   NaN           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# ...

# %%
d.shape
# Out:
# (1259, 27)

# %% [markdown]
# ## Cleaning the data

# %%
d = d.drop(["comments","self_employed","state","work_interfere"] , axis = 1)

# %%
d
# Out:
#                 Timestamp  Age  Gender         Country family_history  \
# 0     2014-08-27 11:29:31   37  Female   United States             No
# 1     2014-08-27 11:29:37   44       M   United States             No
# 2     2014-08-27 11:29:44   32    Male          Canada             No
# 3     2014-08-27 11:29:46   31    Male  United Kingdom            Yes
# 4     2014-08-27 11:30:22   31    Male   United States             No
# ...                   ...  ...     ...             ...            ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom             No
# 1255  2015-09-26 01:07:35   32    Male   United States            Yes
# 1256  2015-11-07 12:36:58   34    male   United States            Yes
# 1257  2015-11-30 21:25:06   46       f   United States             No
# 1258  2016-02-01 23:04:31   25    Male   United States            Yes
#
#      treatment    no_employees remote_work tech_company    benefits  ...  \
# ...

# %%
d.head()
# Out:
#              Timestamp  Age  Gender         Country family_history treatment  \
# 0  2014-08-27 11:29:31   37  Female   United States             No       Yes
# 1  2014-08-27 11:29:37   44       M   United States             No        No
# 2  2014-08-27 11:29:44   32    Male          Canada             No        No
# 3  2014-08-27 11:29:46   31    Male  United Kingdom            Yes       Yes
# 4  2014-08-27 11:30:22   31    Male   United States             No        No
#
#      no_employees remote_work tech_company    benefits  ...   anonymity  \
# 0            6-25          No          Yes         Yes  ...         Yes
# 1  More than 1000          No           No  Don't know  ...  Don't know
# 2            6-25          No          Yes          No  ...  Don't know
# 3          26-100          No          Yes          No  ...          No
# 4         100-500         Yes          Yes         Yes  ...  Don't know
#
# ...

# %%
d.isnull().sum()
# Out:
# Timestamp                    0
# Age                          0
# Gender                       0
# Country                      0
# family_history               0
# treatment                    0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# wellness_program             0
# seek_help                    0
# anonymity                    0
# leave                        0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_health_interview      0
# phys_health_interview        0
# mental_vs_physical           0
# obs_consequence              0
# dtype: int64

# %%
d.describe()
# Out:
#                 Age
# count  1.259000e+03
# mean   7.942815e+07
# std    2.818299e+09
# min   -1.726000e+03
# 25%    2.700000e+01
# 50%    3.100000e+01
# 75%    3.600000e+01
# max    1.000000e+11

# %%
dir(d.describe())
# Out:
# ['Age',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
np.round(d.describe(), 2)
# Out:
#                 Age
# count  1.259000e+03
# mean   7.942815e+07
# std    2.818299e+09
# min   -1.726000e+03
# 25%    2.700000e+01
# 50%    3.100000e+01
# 75%    3.600000e+01
# max    1.000000e+11

# %%
np.round(d.describe(), 2).T
# Out:
#       count         mean           std     min   25%   50%   75%           max
# Age  1259.0  79428148.31  2.818299e+09 -1726.0  27.0  31.0  36.0  1.000000e+11

# %%
np.round(d.describe(), 2).T[['count','mean', 'std', 'min', 'max']]
# Out:
#       count         mean           std     min           max
# Age  1259.0  79428148.31  2.818299e+09 -1726.0  1.000000e+11
